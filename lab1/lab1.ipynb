# %% [markdown]
# # Комп'ютерний практикум ! (1)
#
# **Oleh Radchenko** _BC-81_

# %%
import pandas as pd

# %%
new_df = pd.DataFrame(
    {
"col1": ["BC-81", "81", 20, "Karabinskiy", "Hladkyi", "DataScience_1"],
"col2": ["BC-82", "82", 10, "Ivanov", "asd", "DataScience_2"],
"col3": ["BC-83", "83", 15, "Kiselev", "asd1", "DataScience_3"],
"col4": ["BC-84", "84", 30, "Petrov", "asd2", "DataScience_4"],
"col5": ["BC-85", "85", 35, "Popov", "yolo", "DataScience_5"],
"col6": ["BC-86", "86", 40, "Volnov", "asd3", "DataScience_6"],
    })

new_df
# Out:
#             col1           col2           col3           col4           col5  \
# 0          BC-81          BC-82          BC-83          BC-84          BC-85
# 1             81             82             83             84             85
# 2             20             10             15             30             35
# 3    Karabinskiy         Ivanov        Kiselev         Petrov          Popov
# 4        Hladkyi            asd           asd1           asd2           yolo
# 5  DataScience_1  DataScience_2  DataScience_3  DataScience_4  DataScience_5
#
#             col6
# 0          BC-86
# 1             86
# 2             40
# 3         Volnov
# 4           asd3
# 5  DataScience_6

# %% [markdown]
# 2. **Import *.csv data**

# %%
path = "D:/kpi/4sem/bmd/lab1/data/justdoit_tweets_2018_09_07_2.csv"
data = pd.read_csv(path, encoding = "utf-8")

print(type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
import os 
print ("The directory we are working in is: {}".format(os.getcwd()))
# Out:
# The directory we are working in is: D:\kpi\4sem\bmd\lab1

# %%
path = "D:/kpi/4sem/bmd/lab1/data/justdoit_tweets_2018_09_07_2.csv"
data = pd.read_csv(path, encoding = "utf-8")

# %%
data
# Out:
#       tweet_contributors                                  tweet_coordinates  \
# 0                    NaN                                                NaN
# 1                    NaN                                                NaN
# 2                    NaN                                                NaN
# 3                    NaN  {'type': 'Point', 'coordinates': [-86.45594032...
# 4                    NaN                                                NaN
# ...                  ...                                                ...
# 5084                 NaN                                                NaN
# 5085                 NaN                                                NaN
# 5086                 NaN                                                NaN
# 5087                 NaN                                                NaN
# 5088                 NaN                                                NaN
#
# ...

# %%
data.shape
# Out:
# (5089, 72)

# %%
data.head(5)
# Out:
#    tweet_contributors                                  tweet_coordinates  \
# 0                 NaN                                                NaN
# 1                 NaN                                                NaN
# 2                 NaN                                                NaN
# 3                 NaN  {'type': 'Point', 'coordinates': [-86.45594032...
# 4                 NaN                                                NaN
#
#                  tweet_created_at tweet_display_text_range  \
# 0  Fri Sep 07 16:25:06 +0000 2018                  [0, 75]
# 1  Fri Sep 07 16:24:59 +0000 2018                 [0, 237]
# 2  Fri Sep 07 16:24:50 +0000 2018                 [0, 176]
# 3  Fri Sep 07 16:24:44 +0000 2018                  [0, 88]
# 4  Fri Sep 07 16:24:39 +0000 2018                 [0, 132]
#
#                                       tweet_entities  \
# 0  {'hashtags': [{'text': 'quote', 'indices': [47...
# 1  {'hashtags': [{'text': 'hero', 'indices': [90,...
# ...

# %%
data.tail(5)
# Out:
#       tweet_contributors tweet_coordinates                tweet_created_at  \
# 5084                 NaN               NaN  Fri Sep 07 00:18:24 +0000 2018
# 5085                 NaN               NaN  Fri Sep 07 00:18:14 +0000 2018
# 5086                 NaN               NaN  Fri Sep 07 00:18:05 +0000 2018
# 5087                 NaN               NaN  Fri Sep 07 00:17:49 +0000 2018
# 5088                 NaN               NaN  Fri Sep 07 00:17:13 +0000 2018
#
#      tweet_display_text_range  \
# 5084                  [0, 32]
# 5085                  [0, 79]
# 5086                 [0, 132]
# 5087                  [0, 62]
# 5088                  [0, 78]
#
#                                          tweet_entities  \
# 5084  {'hashtags': [{'text': 'JustDoIt', 'indices': ...
# 5085  {'hashtags': [{'text': 'MGK', 'indices': [31, ...
# 5086  {'hashtags': [{'text': 'MamaSaidKnockYouOut', ...
# 5087  {'hashtags': [{'text': 'USOpen2018', 'indices'...
# ...

# %%
data.describe()
# Out:
#        tweet_contributors  tweet_favorite_count      tweet_id  tweet_id_str  \
# count                 0.0           5089.000000  5.089000e+03  5.089000e+03
# mean                  NaN              4.469444  1.037973e+18  1.037973e+18
# std                   NaN             76.144906  8.067564e+13  8.067564e+13
# min                   NaN              0.000000  1.037857e+18  1.037857e+18
# 25%                   NaN              0.000000  1.037897e+18  1.037897e+18
# 50%                   NaN              0.000000  1.037961e+18  1.037961e+18
# 75%                   NaN              1.000000  1.038052e+18  1.038052e+18
# max                   NaN           4887.000000  1.038101e+18  1.038101e+18
#
#        tweet_in_reply_to_status_id  tweet_in_reply_to_status_id_str  \
# count                 9.420000e+02                     9.420000e+02
# mean                  1.037801e+18                     1.037801e+18
# std                   8.287548e+14                     8.287548e+14
# ...

# %%
data['tweet_id'].describe()
# Out:
# count    5.089000e+03
# mean     1.037973e+18
# std      8.067564e+13
# min      1.037857e+18
# 25%      1.037897e+18
# 50%      1.037961e+18
# 75%      1.038052e+18
# max      1.038101e+18
# Name: tweet_id, dtype: float64

# %%
data['tweet_created_at'].describe()
# Out:
# count                               5089
# unique                              4730
# top       Fri Sep 07 02:56:01 +0000 2018
# freq                                   6
# Name: tweet_created_at, dtype: object

# %%
cut_data = data.iloc[0:10, :]

cut_data
# Out:
#    tweet_contributors                                  tweet_coordinates  \
# 0                 NaN                                                NaN
# 1                 NaN                                                NaN
# 2                 NaN                                                NaN
# 3                 NaN  {'type': 'Point', 'coordinates': [-86.45594032...
# 4                 NaN                                                NaN
# 5                 NaN                                                NaN
# 6                 NaN                                                NaN
# 7                 NaN                                                NaN
# 8                 NaN                                                NaN
# 9                 NaN                                                NaN
#
#                  tweet_created_at tweet_display_text_range  \
# 0  Fri Sep 07 16:25:06 +0000 2018                  [0, 75]
# ...

# %%
new_data = ["gr1", "gr1", "gr1", "gr1", "gr2", "gr2", "gr2", "gr2", "gr2", "gr2"]
cut_data.insert(1, "Group", new_data)
cut_data
# Out:
#    tweet_contributors Group  \
# 0                 NaN   gr1
# 1                 NaN   gr1
# 2                 NaN   gr1
# 3                 NaN   gr1
# 4                 NaN   gr2
# 5                 NaN   gr2
# 6                 NaN   gr2
# 7                 NaN   gr2
# 8                 NaN   gr2
# 9                 NaN   gr2
#
#                                    tweet_coordinates  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  {'type': 'Point', 'coordinates': [-86.45594032...
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
# ...

# %% [markdown]
# 2. Using GroupBy()

# %%
cut_data.groupby('Group').describe()
# Out:
#       tweet_contributors                              tweet_favorite_count  \
#                    count mean std min 25% 50% 75% max                count
# Group
# gr1                  0.0  NaN NaN NaN NaN NaN NaN NaN                  4.0
# gr2                  0.0  NaN NaN NaN NaN NaN NaN NaN                  6.0
#
#             ... user_time_zone     user_utc_offset                           \
#       mean  ...            75% max           count mean std min 25% 50% 75%
# Group       ...
# gr1    0.0  ...            NaN NaN             0.0  NaN NaN NaN NaN NaN NaN
# gr2    0.0  ...            NaN NaN             0.0  NaN NaN NaN NaN NaN NaN
#
#
#       max
# Group
# gr1   NaN
# gr2   NaN
#
# [2 rows x 160 columns]

# %%
cut_data.to_csv("D:/kpi/4sem/bmd/lab1/cutDataOutput.csv", encoding='utf-8')

# %%
data.to_csv('D:/kpi/4sem/bmd/lab1/newDataOutput.csv', encoding='utf-8')

# %%
data.dtypes()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-e265660bf664> in <module>
# ----> 1 data.dtypes()
#
# TypeError: 'Series' object is not callable
